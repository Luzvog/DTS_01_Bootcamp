# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # <b> Práctica Clase 6 </b> <br>

# %% [markdown]
# ## <b> Ejercicio 1</b>
#
# *   Ítems a resolver:
#
#     1)  Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash".<br>
#
# *   Consideraciones:<br>
#
#     1)  Se puede utilizar la función provista. <br>
#
#     ```Python
#         def hash_function(key):
#             return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))
#         print(hash_function('pato'))
#         print(hash_function('tapo'))
#         >>> 1807
#         >>> 1799
#     ```
#
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### <b> Resolución </b>

# %% [markdown]
# 1)  Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash". <br>
#
#     ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import pandas as pd

df = pd.read_csv('Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1')
df.head(10)
# Out:
#   Código de país Nombre del país                   Región   Año CO2 (kt)  \
# 0            ABW           Aruba  América Latina y Caribe  1960      NaN
# 1            ABW           Aruba  América Latina y Caribe  1961      NaN
# 2            ABW           Aruba  América Latina y Caribe  1962      NaN
# 3            ABW           Aruba  América Latina y Caribe  1963      NaN
# 4            ABW           Aruba  América Latina y Caribe  1964      NaN
# 5            ABW           Aruba  América Latina y Caribe  1965      NaN
# 6            ABW           Aruba  América Latina y Caribe  1966      NaN
# 7            ABW           Aruba  América Latina y Caribe  1967      NaN
# 8            ABW           Aruba  América Latina y Caribe  1968      NaN
# 9            ABW           Aruba  América Latina y Caribe  1969      NaN
#
#    CO2 per cápita (toneladas métricas)
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# ...

# %%
df = df.dropna()
df.head(10)
# Out:
#    Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26            ABW           Aruba  América Latina y Caribe  1986   179,683
# 27            ABW           Aruba  América Latina y Caribe  1987   447,374
# 28            ABW           Aruba  América Latina y Caribe  1988   612,389
# 29            ABW           Aruba  América Latina y Caribe  1989   649,059
# 30            ABW           Aruba  América Latina y Caribe  1990  1.840,83
# 31            ABW           Aruba  América Latina y Caribe  1991  1.928,84
# 32            ABW           Aruba  América Latina y Caribe  1992  1.723,49
# 33            ABW           Aruba  América Latina y Caribe  1993  1.771,16
# 34            ABW           Aruba  América Latina y Caribe  1994  1.763,83
# 35            ABW           Aruba  América Latina y Caribe  1995  1.782,16
#
#     CO2 per cápita (toneladas métricas)
# 26                             2.868319
# 27                             7.234964
# ...

# %%
df.dropna(inplace = True)
df.head(10)
# Out:
#    Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26            ABW           Aruba  América Latina y Caribe  1986   179,683
# 27            ABW           Aruba  América Latina y Caribe  1987   447,374
# 28            ABW           Aruba  América Latina y Caribe  1988   612,389
# 29            ABW           Aruba  América Latina y Caribe  1989   649,059
# 30            ABW           Aruba  América Latina y Caribe  1990  1.840,83
# 31            ABW           Aruba  América Latina y Caribe  1991  1.928,84
# 32            ABW           Aruba  América Latina y Caribe  1992  1.723,49
# 33            ABW           Aruba  América Latina y Caribe  1993  1.771,16
# 34            ABW           Aruba  América Latina y Caribe  1994  1.763,83
# 35            ABW           Aruba  América Latina y Caribe  1995  1.782,16
#
#     CO2 per cápita (toneladas métricas)
# 26                             2.868319
# 27                             7.234964
# ...

# %%
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
ClaveHash = [ hash_function(elmt) for elmt in df['Código de país']]

# %%
df.insert(loc = 0, column = 'Clave Hash', value = ClaveHash, allow_duplicates = True)
df.head(10)
# Out:
#     Clave Hash Código de país Nombre del país                   Región   Año  \
# 26         910            ABW           Aruba  América Latina y Caribe  1986
# 27         910            ABW           Aruba  América Latina y Caribe  1987
# 28         910            ABW           Aruba  América Latina y Caribe  1988
# 29         910            ABW           Aruba  América Latina y Caribe  1989
# 30         910            ABW           Aruba  América Latina y Caribe  1990
# 31         910            ABW           Aruba  América Latina y Caribe  1991
# 32         910            ABW           Aruba  América Latina y Caribe  1992
# 33         910            ABW           Aruba  América Latina y Caribe  1993
# 34         910            ABW           Aruba  América Latina y Caribe  1994
# 35         910            ABW           Aruba  América Latina y Caribe  1995
#
#     CO2 (kt)  CO2 per cápita (toneladas métricas)
# 26   179,683                             2.868319
# ...

# %% [markdown]
# ## <b> Ejercicio 2</b>
#
# *   Ítems a resolver:
#
#     1)  A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región".<br>
#
#     ```Python
#         import pandas as pd
#         df = pd.read_csv('Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1')
#     ```
#
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### <b> Resolución </b>

# %% [markdown]
# 1)  A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región".<br>
#
#     ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
df2 = (df.drop_duplicates(subset = 'Clave Hash')).loc[:, ['Clave Hash', 'Código de país', 'Nombre del país', 'Región']]

df2.head(10)
# Out:
#      Clave Hash Código de país         Nombre del país  \
# 26          910            ABW                   Aruba
# 87          870            AND                 Andorra
# 104         858            AFG              Afganistán
# 156         893            AGO                  Angola
# 208         856            ALB                 Albania
# 260         886            ARE  Emiratos Árabes Unidos
# 312         894            ARG               Argentina
# 396         918            ARM                 Armenia
# 468         900            ATG       Antigua y Barbuda
# 520         951            AUS               Australia
#
#                               Región
# 26           América Latina y Caribe
# 87             Europa y Asia Central
# 104                      Sur de Asia
# 156              África subsahariana
# 208            Europa y Asia Central
# 260  Oriente Medio y Norte de África
# 312          América Latina y Caribe
# 396            Europa y Asia Central
# ...
